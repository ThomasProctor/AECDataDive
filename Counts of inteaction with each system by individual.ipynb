# %%
from __future__ import division
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('datapath.txt', 'r') as f:
    datapath = f.readlines()[0].strip()

# %%
cyf_path = 'CYF Active 2010 to 2016-11-09(1).csv'

# %%
cyf = pd.read_csv(datapath + cyf_path, usecols=['MCI_ID'])

# %%
homeless_path = 'HomelessShelters(1).csv'

# %%
# %ls $datapath
# Out:
# Behavioral Health Services.csv        HomelessShelters(1).csv
# CYF Active 2010 to 2016-11-09(1).csv  IDS Variables.xlsx
# CYF Active 2010 to 2016-11-09.csv     rp_placements_clean.csv

# %%
behavioral_path = 'Behavioral Health Services.csv'

# %%
placement_path = 'rp_placements_clean.csv'

# %%
homeless = pd.read_csv(datapath + homeless_path, usecols=['MCI_ID_OR_HMIS_CLIENT_ID'])
behavioral = pd.read_csv(datapath + behavioral_path, usecols=['MCI_UNIQ_ID'])
placement = pd.read_csv(datapath + placement_path, usecols=['MCI_ID'])

# %%
datasets = [homeless, behavioral, placement, cyf]

# %%
for i in range(len(datasets)):
    datasets[i] = datasets[i][datasets[i][datasets[i].columns[0]] >= 1e9]

# %%
counts = [i.groupby(i[i.columns[0]])[i.columns[0]].count() for i in datasets]

# %%
count_names = ['N_HOMELESS', "N_BEHAVIORAL", "N_PLACEMENTS", "N_CYF"]

# %%
for i in range(len(counts)):
    counts[i].name = count_names[i]

# %%
homeless['IN_HOMELESS'] = 1
behavioral['IN_BEHAVIORAL'] = 1
placement['IN_PLACEMENT'] = 1
cyf['IN_CYF'] = 1

# %%
homeless.drop_duplicates(subset=['MCI_ID_OR_HMIS_CLIENT_ID'], inplace=True)
behavioral.drop_duplicates(subset=['MCI_UNIQ_ID'], inplace=True)
placement.drop_duplicates(subset=['MCI_ID'], inplace=True)
cyf.drop_duplicates(subset=['MCI_ID'], inplace=True)

# %%
all_datasets = pd.DataFrame()
for i in counts:
    all_datasets = all_datasets.join(i, how='outer')

# %%
all_datasets.dropna().index.to_series().to_csv('MCI_IDS_in_all_systems.csv')

# %%
all_datasets.fillna(0, inplace=True)

# %%
all_datasets[((all_datasets['N_HOMELESS'] > 0) & (all_datasets['N_BEHAVIORAL']))]
# Out:
#               N_HOMELESS  N_BEHAVIORAL  N_PLACEMENTS  N_CYF
# 1.000000e+09         1.0          10.0           0.0    0.0
# 1.000000e+09         4.0           1.0           0.0    1.0
# 1.000001e+09         1.0         108.0           3.0    1.0
# 1.000001e+09         1.0           4.0           0.0    1.0
# 1.000001e+09         1.0          45.0           0.0    0.0
# 1.000002e+09         1.0          81.0           3.0    1.0
# 1.000004e+09         1.0          81.0           0.0    2.0
# 1.000047e+09         1.0          16.0           0.0    1.0
# 1.000047e+09         1.0          13.0           1.0    1.0
# 1.000047e+09         3.0           7.0           3.0    1.0
# 1.000048e+09         1.0         187.0           0.0    1.0
# 1.000048e+09         2.0         814.0          10.0    3.0
# 1.000048e+09         1.0          18.0           2.0    1.0
# 1.000048e+09         1.0         257.0           0.0    2.0
# 1.000049e+09         1.0           4.0           0.0    1.0
# 1.000049e+09         1.0          16.0           6.0    1.0
# 1.000049e+09         1.0        1145.0          18.0    1.0
# 1.000049e+09         1.0         208.0           0.0    1.0
# 1.000049e+09         1.0          55.0          13.0    2.0
# 1.000050e+09         1.0          30.0           0.0    1.0
# 1.000050e+09         2.0           3.0           0.0    1.0
# 1.000050e+09         2.0           2.0           0.0    1.0
# 1.000050e+09         1.0         753.0           1.0    1.0
# 1.000051e+09         1.0          24.0           0.0    1.0
# 1.000051e+09         1.0          96.0           0.0    1.0
# 1.000052e+09         1.0           1.0           0.0    1.0
# 1.000052e+09         4.0          54.0           1.0    1.0
# 1.000052e+09         2.0         108.0           0.0    1.0
# 1.000053e+09         1.0          78.0           2.0    1.0
# 1.000053e+09         2.0          20.0           3.0    1.0
# ...                  ...           ...           ...    ...
# 1.000806e+09         3.0           9.0           0.0    1.0
# 1.000806e+09         2.0          50.0           0.0    0.0
# 1.000806e+09         2.0          36.0           0.0    0.0
# 1.000806e+09         2.0           3.0           0.0    0.0
# 1.000806e+09         1.0           7.0           0.0    0.0
# 1.000807e+09         1.0         150.0           0.0    0.0
# 1.000807e+09         1.0           5.0           0.0    0.0
# 1.000807e+09         1.0           2.0           0.0    0.0
# 1.000808e+09         1.0          83.0           0.0    0.0
# 1.000808e+09         3.0           5.0           0.0    1.0
# 1.000810e+09         1.0          33.0           0.0    0.0
# 1.000810e+09         1.0           3.0           1.0    1.0
# 1.000811e+09         2.0           4.0           0.0    1.0
# 1.000812e+09         1.0           2.0           0.0    0.0
# 1.000813e+09         1.0          37.0           0.0    0.0
# 1.000815e+09         1.0         907.0           0.0    0.0
# 1.000815e+09         1.0           2.0           1.0    1.0
# 1.000816e+09         1.0           2.0           1.0    1.0
# 1.000816e+09         1.0           9.0           0.0    1.0
# 1.000816e+09         1.0           2.0           0.0    1.0
# 1.000818e+09         4.0          34.0           0.0    0.0
# 1.000819e+09         1.0          35.0           0.0    1.0
# 1.000819e+09         1.0           3.0           2.0    1.0
# 1.000821e+09         2.0           3.0           0.0    1.0
# 1.000822e+09         1.0           1.0           4.0    1.0
# 1.000824e+09         2.0          15.0           0.0    0.0
# 1.000826e+09         1.0           6.0           0.0    0.0
# 1.000829e+09         2.0           7.0           0.0    0.0
# 1.000834e+09         1.0           2.0           0.0    0.0
# 1.000838e+09         1.0         120.0           0.0    0.0
#
# [1910 rows x 4 columns]
